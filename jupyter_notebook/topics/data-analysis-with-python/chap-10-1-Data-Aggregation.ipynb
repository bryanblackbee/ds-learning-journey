# %% [markdown]
# # Chapter 10 - Data Aggregation and Group Operations

# %% [markdown]
# ## Groupby Mechanics

# %%
import pandas as pd

# %%
# Read from CSV file
df = pd.read_csv('dataset-A3-loans.csv')
display(df.head(8))
# Out:
#          id  funded_amount        term  interest_rate grade employee_length  \
# 0    721751         7000.0   36 months          14.91     D         2 years
# 1  40277218        16800.0   60 months          16.49     D         4 years
# 2  68416017         1500.0   36 months           9.17     B       10+ years
# 3  59481461         8000.0   36 months          12.29     C         2 years
# 4     73003         3200.0   36 months           9.96     B        < 1 year
# 5  55917749         5000.0   36 months          12.29     C       10+ years
# 6   1149328        11500.0   36 months          16.29     C         2 years
# 7   1614457         6000.0   36 months          15.80     C         5 years
#
#   home_ownership  annual_income             purpose               title
# 0           RENT        46000.0  debt_consolidation        Debt Removal
# 1           RENT        45500.0    home_improvement    Home improvement
# 2       MORTGAGE        83000.0      major_purchase      Major purchase
# 3           RENT        74000.0  debt_consolidation  Debt consolidation
# 4       MORTGAGE       150000.0               other        New Bathroom
# 5       MORTGAGE        55000.0    home_improvement    Home improvement
# 6       MORTGAGE        68000.0         credit_card         Credit Card
# 7       MORTGAGE        36000.0  debt_consolidation  Debt consolidation

# %% [markdown]
# Consider putting all the loans in the same grade together and finding some descriptive statistics of a column. To do so, use the `Series` that you want to calculate the descriptive stats on and group using the `Series` where the labels are contained.

# %%
df_grouped = df['funded_amount'].groupby(df['grade'])
print(df_grouped)
# Out:
# <pandas.core.groupby.SeriesGroupBy object at 0x11750cac8>

# %% [markdown]
# After performing a `groupby()`, its result is a `GroupBy` object. It has not computed anything, and is an abstract object. The function after this will be human-readable and usable.
#
# Calling `.mean()` will give the mean of each `grade` of loans. It has been aggregated using the grouping key, producing a new `Series` that is now indexed by the unique values in the `grade` column.

# %%
df_grouped.mean()
# Out:
# grade
# A    12083.333333
# B    12517.857143
# C    10670.000000
# D    12568.750000
# E    18683.333333
# F    25000.000000
# Name: funded_amount, dtype: float64

# %% [markdown]
# Grouping can also be done on multiple keys.

# %%
# Pay attention to the list in the groupby function.
ir_means = df['interest_rate'].groupby([df['grade'], df['term']]).mean()
display(ir_means)
# Out:
# grade  term
# A       36 months     7.086667
# B       36 months    10.752500
#         60 months    10.122000
# C       36 months    13.820909
#         60 months    13.670000
# D       36 months    16.385000
#         60 months    17.030000
# E       36 months    18.545000
#         60 months    20.500000
# F       60 months    23.760000
# Name: interest_rate, dtype: float64

# %% [markdown]
# Since this is a `Series`, it can be `unstacked()` and each unique `term` will have its own column. Recall that the columns take a hierarchical index form, having the same number of columns as the number of unique values for `term`.

# %%
ir_by_term_df = ir_means.unstack()

# Also note some values are missing as they do not exist in the Series before unstacking
display(ir_by_term_df) 
print(ir_by_term_df.index)
print(ir_by_term_df.columns)
# Out:
# term    36 months   60 months
# grade
# A        7.086667         NaN
# B       10.752500      10.122
# C       13.820909      13.670
# D       16.385000      17.030
# E       18.545000      20.500
# F             NaN      23.760
# Index(['A', 'B', 'C', 'D', 'E', 'F'], dtype='object', name='grade')
# Index([' 36 months', ' 60 months'], dtype='object', name='term')

# %% [markdown]
# In the more common expression, use `df.groupby(key)` to group data.

# %%
# This will calculate mean for all columns. Some columns have no meaning, like id
all_agg = df.groupby('employee_length').mean()
display(all_agg)
# This will only calculate for one column

funded_amt_agg = df.groupby('employee_length')['funded_amount'].mean()
display(funded_amt_agg)
# Out:
#                            id  funded_amount  interest_rate  annual_income
# employee_length
# 1 year           2.926997e+07   11750.000000      10.432500   76585.750000
# 10+ years        3.686606e+07    9321.428571      11.587857   65766.857143
# 2 years          3.157648e+07   11791.666667      14.635000   62512.500000
# 3 years          6.083330e+07   22300.000000      17.570000   88250.000000
# 4 years          5.782658e+07   14391.666667      13.380000   76166.666667
# 5 years          5.444514e+06   16000.000000      15.450000   75500.000000
# 6 years          2.332386e+07    8395.000000      11.314000   51808.000000
# 7 years          3.032112e+07   10900.000000      10.112500   71500.000000
# 8 years          2.782246e+07   16450.000000      12.245000   74450.500000
# 9 years          4.022430e+07   21237.500000      14.175000   70875.000000
# < 1 year         3.398418e+07   14900.000000      12.326667  107666.666667
# employee_length
# 1 year       11750.000000
# 10+ years     9321.428571
# 2 years      11791.666667
# 3 years      22300.000000
# 4 years      14391.666667
# 5 years      16000.000000
# 6 years       8395.000000
# 7 years      10900.000000
# 8 years      16450.000000
# 9 years      21237.500000
# < 1 year     14900.000000
# Name: funded_amount, dtype: float64

# %% [markdown]
# A general `groupby()` function that is useful is `.size()`

# %%
df.groupby('term').size()
# Out:
# term
#  36 months    37
#  60 months    13
# dtype: int64

# %% [markdown]
# <hr>
# To look in detail what is in the `groupby` object, iterate through it. Iterating it generates a sequence of tuples containing the group name and the subset of data.

# %%
for n, x in df.groupby('employee_length'):
    print(n)
    display(x)
# Out:
# 1 year
#           id  funded_amount        term  interest_rate grade employee_length  \
# 9     290605        15000.0   36 months           9.45     B          1 year
# 19  56994235         6000.0   36 months          10.99     B          1 year
# 29  58350400        20000.0   36 months           9.17     B          1 year
# 33   1444634         6000.0   36 months          12.12     B          1 year
#
#    home_ownership  annual_income             purpose                    title
# 9            RENT       150000.0               house    Chicago Home Purchase
# 19           RENT        40000.0  debt_consolidation       Debt consolidation
# 29           RENT        76343.0         credit_card  Credit card refinancing
# 33           RENT        40000.0         credit_card             Lending Club
# 10+ years
#           id  funded_amount        term  interest_rate grade employee_length  \
# 2   68416017         1500.0   36 months           9.17     B       10+ years
# 5   55917749         5000.0   36 months          12.29     C       10+ years
# 8   31999103        11000.0   36 months          14.49     C       10+ years
# 12  62166736         4500.0   36 months           5.32     A       10+ years
# 13  62082707         3225.0   36 months          13.33     C       10+ years
# 14   1248751        21000.0   60 months          10.74     B       10+ years
# 34  66583250         4175.0   36 months          17.86     D       10+ years
# 35  43165466         1000.0   36 months          12.69     C       10+ years
# 37  29575450        14400.0   36 months           8.39     A       10+ years
# 38  10119917        10000.0   36 months          11.99     B       10+ years
# 40  12528412         6000.0   36 months          12.49     B       10+ years
# 43   7389445        17500.0   60 months          14.30     C       10+ years
# 45   7695133        14000.0   36 months          10.99     B       10+ years
# 48  57236645        17200.0   60 months           8.18     B       10+ years
#
#    home_ownership  annual_income             purpose                    title
# 2        MORTGAGE        83000.0      major_purchase           Major purchase
# 5        MORTGAGE        55000.0    home_improvement         Home improvement
# 8            RENT        72000.0  debt_consolidation       Debt consolidation
# 12       MORTGAGE        76000.0    home_improvement         Home improvement
# 13            OWN        60000.0         credit_card  Credit card refinancing
# 14           RENT        77983.0  debt_consolidation       Debt Consolidation
# 34           RENT        25000.0  debt_consolidation       Debt consolidation
# 35       MORTGAGE        55000.0            vacation                 Vacation
# 37       MORTGAGE        67000.0  debt_consolidation       Debt consolidation
# 38           RENT       150000.0         credit_card                CC Payoff
# 40       MORTGAGE        56000.0      major_purchase           Major purchase
# 43       MORTGAGE        40000.0         credit_card  Credit card refinancing
# 45            OWN        54000.0  debt_consolidation       Debt consolidation
# 48           RENT        49753.0  debt_consolidation       Debt consolidation
# 2 years
#           id  funded_amount        term  interest_rate grade employee_length  \
# 0     721751         7000.0   36 months          14.91     D         2 years
# 3   59481461         8000.0   36 months          12.29     C         2 years
# 6    1149328        11500.0   36 months          16.29     C         2 years
# 16  62042554        18000.0   60 months          12.29     C         2 years
# 24  10095878        19750.0   60 months          20.50     E         2 years
# 49  55967936         6500.0   36 months          11.53     B         2 years
#
#    home_ownership  annual_income             purpose                    title
# 0            RENT        46000.0  debt_consolidation             Debt Removal
# 3            RENT        74000.0  debt_consolidation       Debt consolidation
# 6        MORTGAGE        68000.0         credit_card              Credit Card
# 16            OWN        48000.0  debt_consolidation       Debt consolidation
# 24       MORTGAGE        99075.0  debt_consolidation       Debt Consolidation
# 49           RENT        40000.0         credit_card  Credit card refinancing
# 3 years
#           id  funded_amount        term  interest_rate grade employee_length  \
# 23  60833297        22300.0   60 months          17.57     D         3 years
#
#    home_ownership  annual_income      purpose                    title
# 23           RENT        88250.0  credit_card  Credit card refinancing
# 4 years
#           id  funded_amount        term  interest_rate grade employee_length  \
# 1   40277218        16800.0   60 months          16.49     D         4 years
# 30  65382755        20375.0   60 months           9.17     B         4 years
# 39  67819776         6000.0   36 months          14.48     C         4 years
#
#    home_ownership  annual_income             purpose               title
# 1            RENT        45500.0    home_improvement    Home improvement
# 30       MORTGAGE        98000.0  debt_consolidation  Debt consolidation
# 39           RENT        85000.0  debt_consolidation  Debt consolidation
# 5 years
#          id  funded_amount        term  interest_rate grade employee_length  \
# 7   1614457         6000.0   36 months           15.8     C         5 years
# 31  9274571        26000.0   60 months           15.1     C         5 years
#
#    home_ownership  annual_income             purpose               title
# 7        MORTGAGE        36000.0  debt_consolidation  Debt consolidation
# 31       MORTGAGE       115000.0  debt_consolidation       Consolidation
# 6 years
#           id  funded_amount        term  interest_rate grade employee_length  \
# 11  42221389         2875.0   36 months          12.69     C         6 years
# 15  39629278        11000.0   36 months           8.67     B         6 years
# 25   6836002        11075.0   36 months          13.05     B         6 years
# 41  18965501        10800.0   36 months          12.49     B         6 years
# 47   8967105         6225.0   36 months           9.67     B         6 years
#
#    home_ownership  annual_income             purpose                    title
# 11           RENT        49040.0  debt_consolidation       Debt consolidation
# 15           RENT        45000.0         credit_card  Credit card refinancing
# 25           RENT        55000.0  debt_consolidation               Lower rate
# 41           RENT        65000.0  debt_consolidation       Debt consolidation
# 47           RENT        45000.0  debt_consolidation           Consolidate LC
# 7 years
#           id  funded_amount        term  interest_rate grade employee_length  \
# 10  49864582        10000.0   60 months          11.53     B         7 years
# 18  38539098         6000.0   36 months           6.03     A         7 years
# 36   8945719         9600.0   36 months           7.90     A         7 years
# 46  23935069        18000.0   36 months          14.99     C         7 years
#
#    home_ownership  annual_income             purpose                    title
# 10            OWN        78000.0         credit_card  Credit card refinancing
# 18           RENT        73000.0         credit_card  Credit card refinancing
# 36       MORTGAGE        90000.0         credit_card           pay off credit
# 46           RENT        45000.0  debt_consolidation       Debt consolidation
# 8 years
#           id  funded_amount        term  interest_rate grade employee_length  \
# 17   4798106        22000.0   36 months          12.12     B         8 years
# 22  41339796         4800.0   36 months          18.25     E         8 years
# 32   2865306         4000.0   36 months           7.62     A         8 years
# 44  62286613        35000.0   60 months          10.99     B         8 years
#
#    home_ownership  annual_income             purpose                    title
# 17           RENT        78000.0         credit_card       Credit Card Payoff
# 22       MORTGAGE        46000.0            vacation                 Vacation
# 32           RENT        71000.0  debt_consolidation       Debt Consolidation
# 44       MORTGAGE       102802.0         credit_card  Credit card refinancing
# 9 years
#           id  funded_amount        term  interest_rate grade employee_length  \
# 21  38514650        22950.0   60 months          12.99     C         9 years
# 26   3702908        25000.0   60 months          23.76     F         9 years
# 27  62399461         3000.0   36 months          12.69     C         9 years
# 42  56280184        34000.0   36 months           7.26     A         9 years
#
#    home_ownership  annual_income             purpose               title
# 21           RENT        50000.0  debt_consolidation  Debt consolidation
# 26       MORTGAGE        68000.0  debt_consolidation  Debt consolidation
# 27           RENT        55500.0                 car       Car financing
# 42       MORTGAGE       110000.0  debt_consolidation  Debt consolidation
# < 1 year
#           id  funded_amount        term  interest_rate grade employee_length  \
# 4      73003         3200.0   36 months           9.96     B        < 1 year
# 20  58723821        10000.0   36 months           8.18     B        < 1 year
# 28  43155702        31500.0   36 months          18.84     E        < 1 year
#
#    home_ownership  annual_income             purpose               title
# 4        MORTGAGE       150000.0               other        New Bathroom
# 20       MORTGAGE        43000.0  debt_consolidation  Debt consolidation
# 28           RENT       130000.0      major_purchase      Major purchase

# %% [markdown]
# In the case of multiple keys, the first element contains the tuple containing column names.

# %%
for (tm, gr), x in df.groupby(['term', 'grade']):
    print("< %s|%s >" % (tm.strip(), gr.strip()))
    display(x)
# Out:
# < 36 months|A >
#           id  funded_amount        term  interest_rate grade employee_length  \
# 12  62166736         4500.0   36 months           5.32     A       10+ years
# 18  38539098         6000.0   36 months           6.03     A         7 years
# 32   2865306         4000.0   36 months           7.62     A         8 years
# 36   8945719         9600.0   36 months           7.90     A         7 years
# 37  29575450        14400.0   36 months           8.39     A       10+ years
# 42  56280184        34000.0   36 months           7.26     A         9 years
#
#    home_ownership  annual_income             purpose                    title
# 12       MORTGAGE        76000.0    home_improvement         Home improvement
# 18           RENT        73000.0         credit_card  Credit card refinancing
# 32           RENT        71000.0  debt_consolidation       Debt Consolidation
# 36       MORTGAGE        90000.0         credit_card           pay off credit
# 37       MORTGAGE        67000.0  debt_consolidation       Debt consolidation
# 42       MORTGAGE       110000.0  debt_consolidation       Debt consolidation
# < 36 months|B >
#           id  funded_amount        term  interest_rate grade employee_length  \
# 2   68416017         1500.0   36 months           9.17     B       10+ years
# 4      73003         3200.0   36 months           9.96     B        < 1 year
# 9     290605        15000.0   36 months           9.45     B          1 year
# 15  39629278        11000.0   36 months           8.67     B         6 years
# 17   4798106        22000.0   36 months          12.12     B         8 years
# 19  56994235         6000.0   36 months          10.99     B          1 year
# 20  58723821        10000.0   36 months           8.18     B        < 1 year
# 25   6836002        11075.0   36 months          13.05     B         6 years
# 29  58350400        20000.0   36 months           9.17     B          1 year
# 33   1444634         6000.0   36 months          12.12     B          1 year
# 38  10119917        10000.0   36 months          11.99     B       10+ years
# 40  12528412         6000.0   36 months          12.49     B       10+ years
# 41  18965501        10800.0   36 months          12.49     B         6 years
# 45   7695133        14000.0   36 months          10.99     B       10+ years
# 47   8967105         6225.0   36 months           9.67     B         6 years
# 49  55967936         6500.0   36 months          11.53     B         2 years
#
#    home_ownership  annual_income             purpose                    title
# 2        MORTGAGE        83000.0      major_purchase           Major purchase
# 4        MORTGAGE       150000.0               other             New Bathroom
# 9            RENT       150000.0               house    Chicago Home Purchase
# 15           RENT        45000.0         credit_card  Credit card refinancing
# 17           RENT        78000.0         credit_card       Credit Card Payoff
# 19           RENT        40000.0  debt_consolidation       Debt consolidation
# 20       MORTGAGE        43000.0  debt_consolidation       Debt consolidation
# 25           RENT        55000.0  debt_consolidation               Lower rate
# 29           RENT        76343.0         credit_card  Credit card refinancing
# 33           RENT        40000.0         credit_card             Lending Club
# 38           RENT       150000.0         credit_card                CC Payoff
# 40       MORTGAGE        56000.0      major_purchase           Major purchase
# 41           RENT        65000.0  debt_consolidation       Debt consolidation
# 45            OWN        54000.0  debt_consolidation       Debt consolidation
# 47           RENT        45000.0  debt_consolidation           Consolidate LC
# 49           RENT        40000.0         credit_card  Credit card refinancing
# < 36 months|C >
#           id  funded_amount        term  interest_rate grade employee_length  \
# 3   59481461         8000.0   36 months          12.29     C         2 years
# 5   55917749         5000.0   36 months          12.29     C       10+ years
# 6    1149328        11500.0   36 months          16.29     C         2 years
# 7    1614457         6000.0   36 months          15.80     C         5 years
# 8   31999103        11000.0   36 months          14.49     C       10+ years
# 11  42221389         2875.0   36 months          12.69     C         6 years
# 13  62082707         3225.0   36 months          13.33     C       10+ years
# 27  62399461         3000.0   36 months          12.69     C         9 years
# 35  43165466         1000.0   36 months          12.69     C       10+ years
# 39  67819776         6000.0   36 months          14.48     C         4 years
# 46  23935069        18000.0   36 months          14.99     C         7 years
#
#    home_ownership  annual_income             purpose                    title
# 3            RENT        74000.0  debt_consolidation       Debt consolidation
# 5        MORTGAGE        55000.0    home_improvement         Home improvement
# 6        MORTGAGE        68000.0         credit_card              Credit Card
# 7        MORTGAGE        36000.0  debt_consolidation       Debt consolidation
# 8            RENT        72000.0  debt_consolidation       Debt consolidation
# 11           RENT        49040.0  debt_consolidation       Debt consolidation
# 13            OWN        60000.0         credit_card  Credit card refinancing
# 27           RENT        55500.0                 car            Car financing
# 35       MORTGAGE        55000.0            vacation                 Vacation
# 39           RENT        85000.0  debt_consolidation       Debt consolidation
# 46           RENT        45000.0  debt_consolidation       Debt consolidation
# < 36 months|D >
#           id  funded_amount        term  interest_rate grade employee_length  \
# 0     721751         7000.0   36 months          14.91     D         2 years
# 34  66583250         4175.0   36 months          17.86     D       10+ years
#
#    home_ownership  annual_income             purpose               title
# 0            RENT        46000.0  debt_consolidation        Debt Removal
# 34           RENT        25000.0  debt_consolidation  Debt consolidation
# < 36 months|E >
#           id  funded_amount        term  interest_rate grade employee_length  \
# 22  41339796         4800.0   36 months          18.25     E         8 years
# 28  43155702        31500.0   36 months          18.84     E        < 1 year
#
#    home_ownership  annual_income         purpose           title
# 22       MORTGAGE        46000.0        vacation        Vacation
# 28           RENT       130000.0  major_purchase  Major purchase
# < 60 months|B >
#           id  funded_amount        term  interest_rate grade employee_length  \
# 10  49864582        10000.0   60 months          11.53     B         7 years
# 14   1248751        21000.0   60 months          10.74     B       10+ years
# 30  65382755        20375.0   60 months           9.17     B         4 years
# 44  62286613        35000.0   60 months          10.99     B         8 years
# 48  57236645        17200.0   60 months           8.18     B       10+ years
#
#    home_ownership  annual_income             purpose                    title
# 10            OWN        78000.0         credit_card  Credit card refinancing
# 14           RENT        77983.0  debt_consolidation       Debt Consolidation
# 30       MORTGAGE        98000.0  debt_consolidation       Debt consolidation
# 44       MORTGAGE       102802.0         credit_card  Credit card refinancing
# 48           RENT        49753.0  debt_consolidation       Debt consolidation
# < 60 months|C >
#           id  funded_amount        term  interest_rate grade employee_length  \
# 16  62042554        18000.0   60 months          12.29     C         2 years
# 21  38514650        22950.0   60 months          12.99     C         9 years
# 31   9274571        26000.0   60 months          15.10     C         5 years
# 43   7389445        17500.0   60 months          14.30     C       10+ years
#
#    home_ownership  annual_income             purpose                    title
# 16            OWN        48000.0  debt_consolidation       Debt consolidation
# 21           RENT        50000.0  debt_consolidation       Debt consolidation
# 31       MORTGAGE       115000.0  debt_consolidation            Consolidation
# 43       MORTGAGE        40000.0         credit_card  Credit card refinancing
# < 60 months|D >
#           id  funded_amount        term  interest_rate grade employee_length  \
# 1   40277218        16800.0   60 months          16.49     D         4 years
# 23  60833297        22300.0   60 months          17.57     D         3 years
#
#    home_ownership  annual_income           purpose                    title
# 1            RENT        45500.0  home_improvement         Home improvement
# 23           RENT        88250.0       credit_card  Credit card refinancing
# < 60 months|E >
#           id  funded_amount        term  interest_rate grade employee_length  \
# 24  10095878        19750.0   60 months           20.5     E         2 years
#
#    home_ownership  annual_income             purpose               title
# 24       MORTGAGE        99075.0  debt_consolidation  Debt Consolidation
# < 60 months|F >
#          id  funded_amount        term  interest_rate grade employee_length  \
# 26  3702908        25000.0   60 months          23.76     F         9 years
#
#    home_ownership  annual_income             purpose               title
# 26       MORTGAGE        68000.0  debt_consolidation  Debt consolidation

# %% [markdown]
# A useful trick is to convert this technique into a dictionary, using the unique values as the key.

# %%
grade_dict = dict(list(df.groupby('grade')))
display(grade_dict['D'])
# Out:
#           id  funded_amount        term  interest_rate grade employee_length  \
# 0     721751         7000.0   36 months          14.91     D         2 years
# 1   40277218        16800.0   60 months          16.49     D         4 years
# 23  60833297        22300.0   60 months          17.57     D         3 years
# 34  66583250         4175.0   36 months          17.86     D       10+ years
#
#    home_ownership  annual_income             purpose                    title
# 0            RENT        46000.0  debt_consolidation             Debt Removal
# 1            RENT        45500.0    home_improvement         Home improvement
# 23           RENT        88250.0         credit_card  Credit card refinancing
# 34           RENT        25000.0  debt_consolidation       Debt consolidation

# %% [markdown]
# <hr>
# For using `groupby()` objects, it is usual to only look at a subset of columns. It can be done by adding the list after the `groupby()` function.

# %%
funded_groupby = df.groupby('grade')['funded_amount']
print(funded_groupby)
# Out:
# <pandas.core.groupby.SeriesGroupBy object at 0x1175455c0>

# %%
display(funded_groupby.size())
display(funded_groupby.sum())
display(funded_groupby.mean())
display(funded_groupby.std())
# Out:
# grade
# A     6
# B    21
# C    15
# D     4
# E     3
# F     1
# Name: funded_amount, dtype: int64
# grade
# A     72500.0
# B    262875.0
# C    160050.0
# D     50275.0
# E     56050.0
# F     25000.0
# Name: funded_amount, dtype: float64
# grade
# A    12083.333333
# B    12517.857143
# C    10670.000000
# D    12568.750000
# E    18683.333333
# F    25000.000000
# Name: funded_amount, dtype: float64
# grade
# A    11416.902674
# B     7915.602247
# C     7982.728007
# D     8447.222793
# E    13381.921885
# F             NaN
# Name: funded_amount, dtype: float64

# %%
funded_groupby2 = df.groupby(['grade', 'term'])['funded_amount']
print(funded_groupby2)
print(funded_groupby2.mean())
# Out:
# <pandas.core.groupby.SeriesGroupBy object at 0x117562a58>
# grade  term
# A       36 months    12083.333333
# B       36 months     9956.250000
#         60 months    20715.000000
# C       36 months     6872.727273
#         60 months    21112.500000
# D       36 months     5587.500000
#         60 months    19550.000000
# E       36 months    18150.000000
#         60 months    19750.000000
# F       60 months    25000.000000
# Name: funded_amount, dtype: float64

# %% [markdown]
# **References:**
#
# Python for Data Analysis, 2nd Edition, McKinney (2017)
